# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
# From Python Lists
arr = np.array([1, 2, 3])
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])

# Special Arrays
np.zeros((3, 3))
np.ones((2, 4))
np.eye(3)
np.arange(0, 10, 2)
np.linspace(0, 1, 5)
np.random.rand(3, 2)
np.random.randn(3, 2)
# Out:
# array([[-0.67433042,  0.36584356],
#        [ 0.14602206, -0.20634915],
#        [ 0.6081931 , -1.57246238]])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr.shape)
print(arr.ndim)
print(arr.size)
print(arr.dtype)
# Out:
# (2, 3)
# 2
# 6
# int64

# %%
# Basic Math
a = np.array([1, 2, 3])

b = np.array([4, 5, 6])
a + b
a * b
np.sin(a)

# Matrix Multiplication
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
np.dot(A, B)
A @ B

# Aggregation
arr = np.array([1, 2, 3, 4])
arr.sum()
arr.mean()
arr.max()
arr.min()
arr.std()
# Out:
# np.float64(1.118033988749895)

# %%
# 1D Arrays
arr = np.array([1, 2, 3, 4, 5])
arr[0]

arr[1:4]
arr[::2]

# 2D Arrays
arr = np.array([[1, 2, 3], [4, 5, 6]])
arr[0, 1]
arr[:, 1]
arr[1, :2]

# Boolean Indexing
arr = np.array([1, 2, 3, 4, 5])
mask = arr > 3
arr[mask]
# Out:
# array([4, 5])

# %%
# Reshape
arr = np.arange(6)
arr.reshape(2, 3)

# Concatenation
a = np.array([1, 2])
b = np.array([3, 4])
np.concatenate((a, b))

# Stacking
np.vstack((a, b))
np.hstack((a, b))
# Out:
# array([1, 2, 3, 4])

# %%
a = np.array([1, 2, 3])
a + 5 # [6, 7, 8]
# Out:
# array([6, 7, 8])

# %%
np.save('array.npy', arr)
loaded_arr = np.load('array.npy',)

# %%
np.save('array.npy', arr)
